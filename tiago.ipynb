# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('a/bd_mqam.csv')
df = df.drop('Unnamed: 0', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ano           9000 non-null   int64
#  1   sigla_uf      9000 non-null   object
#  2   idade         9000 non-null   int64
#  3   fase_vida     9000 non-null   object
#  4   sexo          9000 non-null   object
#  5   raca_cor      9000 non-null   object
#  6   escolaridade  9000 non-null   object
#  7   peso          9000 non-null   float64
#  8   altura        9000 non-null   float64
#  9   imc           9000 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 703.3+ KB

# %%
df[['idade','peso','altura','imc']].mean()
# Out:
# idade      36.835444
# peso       66.574918
# altura    159.234511
# imc        26.081908
# dtype: float64

# %%
plt.figure(figsize=(25,8))
sns.countplot(df, x='idade')
# Out:
# <Axes: xlabel='idade', ylabel='count'>

# %%
plt.title('Idade')
plt.xlabel(' ')
sns.boxplot(df, x='idade')
# Out:
# <Axes: title={'center': 'Idade'}, xlabel=' '>

# %%
df.sort_values(by=['idade'])
# Out:
#        ano sigla_uf  idade    fase_vida sexo raca_cor  \
# 5846  2020       MG     10  Adolescente    F   Branca
# 8984  2023       MG     10  Adolescente    F   Branca
# 8051  2023       MG     10  Adolescente    M    Parda
# 2917  2017       PA     10  Adolescente    F    Parda
# 6708  2021       PA     10  Adolescente    M    Parda
# ...    ...      ...    ...          ...  ...      ...
# 8075  2023       MG     94        Idoso    M   Branca
# 293   2015       BA     94        Idoso    F   Branca
# 6195  2021       MG     94        Idoso    F    Parda
# 6666  2021       MG     96        Idoso    F    Parda
# 7396  2022       AM    103        Idoso    F  Amarela
#
#                           escolaridade   peso  altura    imc
# 5846  Ensino fundamental 1ª a 4ª série  25.85   132.0  14.35
# 8984                            Nenhum  59.40   148.0  27.12
# 8051  Ensino fundamental 1ª a 4ª série  28.30   126.0  17.83
# 2917               Classe alfabetizada  43.00   150.0  19.11
# ...

# %%
q1 = np.percentile(df['idade'], 25)
q2 = np.percentile(df['idade'], 50)
q3 = np.percentile(df['idade'], 75)

print(q1)
print(q2)
print(q3)
iqr = q3- q1
print(q1 - 1.5 * iqr)
print(q3 + 1.5 * iqr)
# Out:
# 20.0
# 33.0
# 52.0
# -28.0
# 100.0

# %%
plt.title('Peso')
plt.xlabel(' ')
sns.boxplot(df, x='peso')
# Out:
# <Axes: title={'center': 'Peso'}, xlabel=' '>

# %%
q1 = np.percentile(df['peso'], 25)
q2 = np.percentile(df['peso'], 50)
q3 = np.percentile(df['peso'], 75)

print(q1)
print(q2)
print(q3)
iqr = q3- q1
print(q1 - 1.5 * iqr)
print(q3 + 1.5 * iqr)
# Out:
# 55.0
# 65.2
# 77.0
# 22.0
# 110.0

# %%
plt.title('Altura')
plt.xlabel(' ')
sns.boxplot(df, x='altura')
# Out:
# <Axes: title={'center': 'Altura'}, xlabel=' '>

# %%
q1 = np.percentile(df['altura'], 25)
q2 = np.percentile(df['altura'], 50)
q3 = np.percentile(df['altura'], 75)

print(q1)
print(q2)
print(q3)
iqr = q3- q1
print(q1 - 1.5 * iqr)
print(q3 + 1.5 * iqr)
# Out:
# 153.0
# 160.0
# 165.0
# 135.0
# 183.0

# %%
plt.title('Imc')
plt.xlabel(' ')
sns.boxplot(df, x='imc')
# Out:
# <Axes: title={'center': 'Imc'}, xlabel=' '>

# %%
q1 = np.percentile(df['imc'], 25)
q2 = np.percentile(df['imc'], 50)
q3 = np.percentile(df['imc'], 75)

print(q1)
print(q2)
print(q3)
iqr = q3- q1
print(q1 - 1.5 * iqr)
print(q3 + 1.5 * iqr)
# Out:
# 21.8
# 25.4
# 29.572499999999998
# 10.141250000000005
# 41.231249999999996

# %%
plt.title('Raça/Cor')
plt.xlabel(' ')
sns.countplot(df, x='raca_cor')
# Out:
# <Axes: title={'center': 'Raça/Cor'}, xlabel=' ', ylabel='count'>

# %%
fig, ax = plt.subplots(1,figsize=(10,4))
plt.title('Escolaridade')
plt.xlabel(' ')
fig.autofmt_xdate()
sns.countplot(df, x='escolaridade', order=["Nenhum", "Creche", "Pré-escola", "Classe alfabetizada", "Ensino fundamental 1ª a 4ª série", "Ensino fundamental 5ª a 8ª séries", "Ensino fundamental completo", "Ensino fundamental especial", "Ensino fundamental eja - séries iniciais (supletivo 1ª a 4ª)", "Ensino fundamental eja - séries iniciais (supletivo 5ª a 8ª)", "Ensino médio, médio2º ciclo (científico,técnico e etc)", "Ensino médio especial", "Ensino médio eja(supletivo)", "Superior, aperfeiçoamento, especialização, mestrado, doutorado", "Alfabetização para adultos (mobral, etc)"])
plt.show()

# %%
plt.title('Fase da Vida')
plt.xlabel(' ')
sns.countplot(df, x='fase_vida', order=['Adolescente',  'Adulto', 'Idoso'])
# Out:
# <Axes: title={'center': 'Fase da Vida'}, xlabel=' ', ylabel='count'>

# %%
plt.title('Sexo')
plt.xlabel(' ')
sns.countplot(df, x='sexo')
# Out:
# <Axes: title={'center': 'Sexo'}, xlabel=' ', ylabel='count'>

# %%
plt.figure(figsize=(20,8))
plt.title('Estado')
plt.xlabel(' ')
sns.countplot(df, x='sigla_uf')
# Out:
# <Axes: title={'center': 'Estado'}, xlabel=' ', ylabel='count'>

# %%
import math
from scipy.stats import shapiro 

#perform Shapiro-Wilk test for normality
shapiro(df[['idade']])
# Out:
# /home/oliver/.env/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 9000.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=np.float64(0.9416365105465653), pvalue=np.float64(1.7175780785210124e-50))

# %%
df[['idade','peso','altura','imc']].mean()
# Out:
# idade      36.835444
# peso       66.574918
# altura    159.234511
# imc        26.081908
# dtype: float64

# %%
df[['idade','peso','altura','imc']].median()
# Out:
# idade      33.0
# peso       65.2
# altura    160.0
# imc        25.4
# dtype: float64

# %%
df.mode()
# Out:
#     ano sigla_uf  idade fase_vida sexo raca_cor  \
# 0  2015       MG   10.0    Adulto    F    Parda
# 1  2016      NaN    NaN       NaN  NaN      NaN
# 2  2017      NaN    NaN       NaN  NaN      NaN
# 3  2018      NaN    NaN       NaN  NaN      NaN
# 4  2019      NaN    NaN       NaN  NaN      NaN
# 5  2020      NaN    NaN       NaN  NaN      NaN
# 6  2021      NaN    NaN       NaN  NaN      NaN
# 7  2022      NaN    NaN       NaN  NaN      NaN
# 8  2023      NaN    NaN       NaN  NaN      NaN
#
#                        escolaridade  peso  altura   imc
# 0  Ensino fundamental 1ª a 4ª série  60.0   160.0  24.3
# 1                               NaN   NaN     NaN   NaN
# 2                               NaN   NaN     NaN   NaN
# 3                               NaN   NaN     NaN   NaN
# 4                               NaN   NaN     NaN   NaN
# 5                               NaN   NaN     NaN   NaN
# 6                               NaN   NaN     NaN   NaN
# ...

# %%
df[['idade','peso','altura','imc']].std()
# Out:
# idade     19.936005
# peso      18.198992
# altura     9.789089
# imc        6.325372
# dtype: float64

# %%
df[['idade','peso','altura','imc']].var()
# Out:
# idade     397.444304
# peso      331.203312
# altura     95.826265
# imc        40.010331
# dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math



stats.probplot(df['peso'], fit=True, plot=plt)
plt.title(label="Antes")
plt.show()

# %%
peso_norm = np.log(df['peso'])
stats.probplot(peso_norm, fit=True, plot=plt)
plt.title(label="Normalizado")
plt.show()

# %%
mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
stats.probplot(stats.norm.pdf(x, mu, sigma), fit=True, plot=plt)
plt.show()

# %%
stats.probplot(df['idade'], fit=True, plot=plt)
plt.title(label="Antes")
plt.show()

# %%
idade_norm = np.log(df['idade'])
stats.probplot(idade_norm, fit=True, plot=plt)
plt.title(label="Normalizado")
plt.show()

# %%
stats.probplot(df['altura'], fit=True, plot=plt)
plt.title(label="Antes")
plt.show()

# %%
altura_norm = 1/(df['altura'])
stats.probplot(altura_norm, fit=True, plot=plt)
plt.title(label="Normalizado")
plt.show()

# %%
#perform Shapiro-Wilk test for normality
stats.shapiro(peso_norm)
# Out:
# /home/oliver/.env/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 9000.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=np.float64(0.9810805390381946), pvalue=np.float64(6.658926536763378e-33))
