# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df15 = pd.read_csv('a/df15.csv')
df16 = pd.read_csv('a/df16.csv')
df17 = pd.read_csv('a/df17.csv')
df18 = pd.read_csv('a/df18.csv')
df19 = pd.read_csv('a/df19.csv')
df20 = pd.read_csv('a/df20.csv')
df21 = pd.read_csv('a/df21.csv')
df22 = pd.read_csv('a/df22.csv')
df23 = pd.read_csv('a/df23.csv')

# %%
# df08 = pd.read_csv('df08.csv')
# df09 = pd.read_csv('df09.csv')
# df10 = pd.read_csv('df10.csv')
# df11 = pd.read_csv('df11.csv')
# df12 = pd.read_csv('df12.csv')
# df13 = pd.read_csv('df13.csv')
# df14 = pd.read_csv('df14.csv')
df15m = pd.read_csv('df15m.csv')
df16m = pd.read_csv('df16m.csv')
df17m = pd.read_csv('df17m.csv')
df18m = pd.read_csv('df18m.csv')
df19m = pd.read_csv('df19m.csv')
df20m = pd.read_csv('df20m.csv')
df21m = pd.read_csv('df21m.csv')
df22m = pd.read_csv('df22m.csv')
df23m = pd.read_csv('df23m.csv')
df15h = pd.read_csv('df15h.csv')
df16h = pd.read_csv('df16h.csv')
df17h = pd.read_csv('df17h.csv')
df18h = pd.read_csv('df18h.csv')
df19h = pd.read_csv('df19h.csv')
df20h = pd.read_csv('df20h.csv')
df21h = pd.read_csv('df21h.csv')
df22h = pd.read_csv('df22h.csv')
df23h = pd.read_csv('df23h.csv')

# %%
# frames = [df15m, df16m, df17m, df18m, df19m, df20m, df21m, df22m, df23m, df15h, df16h, df17h, df18h, df19h, df20h, df21h, df22h, df23h]
frames = [df15, df16, df17, df18, df19, df20, df21, df22, df23]
df = pd.concat(frames)

# %%
fase_vida ={1: "Menor de 6 meses", 2: "Entre 6 meses a 2 anos", 3: "Entre 2 anos a 5 anos", 4: "Entre 5 anos a 7 anos", 5: "Entre 7 anos a 10 anos", 6: "Adolescente", 7: "Adulto", 8: "Idoso"}
raca_cor ={1: "Branca", 2: "Preta", 3: "Amarela", 4: "Parda", 5: "Indigena", 99: "Sem informacao"}
escolaridade ={1: "Creche", 2: "Pré-escola", 3: "Classe alfabetizada", 4: "Ensino fundamental 1ª a 4ª série", 5: "Ensino fundamental 5ª a 8ª séries", 6: "Ensino fundamental completo", 7: "Ensino fundamental especial", 8: "Ensino fundamental eja - séries iniciais (supletivo 1ª a 4ª)", 9: "Ensino fundamental eja - séries iniciais (supletivo 5ª a 8ª)", 10: "Ensino médio, médio2º ciclo (científico,técnico e etc)", 11: "Ensino médio especial", 12: "Ensino médio eja(supletivo)", 13: "Superior, aperfeiçoamento, especialização, mestrado, doutorado", 14: "Alfabetização para adultos (mobral, etc)", 15: "Nenhum", 99: "Sem inormacao"}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ano           9000 non-null   int64
#  1   sigla_uf      9000 non-null   object
#  2   idade         9000 non-null   int64
#  3   fase_vida     9000 non-null   int64
#  4   sexo          9000 non-null   object
#  5   raca_cor      9000 non-null   int64
#  6   escolaridade  9000 non-null   int64
#  7   peso          9000 non-null   float64
#  8   altura        9000 non-null   float64
#  9   imc           9000 non-null   float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 773.4+ KB

# %%
data = df

# %%
data['raca_cor'] = df['raca_cor'].map(raca_cor)
data['escolaridade'] = df['escolaridade'].map(escolaridade)
data['fase_vida'] = df['fase_vida'].map(fase_vida)
data
# Out:
#       ano sigla_uf  idade    fase_vida sexo raca_cor  \
# 0    2015       PR     55       Adulto    M   Branca
# 1    2015       PA     19  Adolescente    F   Branca
# 2    2015       MG     32       Adulto    F    Preta
# 3    2015       PR     29       Adulto    F   Branca
# 4    2015       MG     15  Adolescente    F   Branca
# ..    ...      ...    ...          ...  ...      ...
# 995  2023       PA     32       Adulto    F    Parda
# 996  2023       PR     52       Adulto    M   Branca
# 997  2023       PA     41       Adulto    F    Parda
# 998  2023       MG     48       Adulto    M   Branca
# 999  2023       MG     11  Adolescente    M    Parda
#
#                           escolaridade  peso  altura    imc
# 0                               Nenhum  72.5   169.0  25.40
# 1                               Nenhum  92.1   168.0  32.60
# 2          Ensino fundamental completo  71.0   161.0  27.40
# 3    Ensino fundamental 5ª a 8ª séries  58.8   163.0  22.10
# ...

# %%
ax = sns.countplot(data=data, x="escolaridade", order=["Creche", "Pré-escola", "Classe alfabetizada", "Ensino fundamental 1ª a 4ª série", "Ensino fundamental 5ª a 8ª séries", "Ensino fundamental completo", "Ensino fundamental especial", "Ensino fundamental eja - séries iniciais (supletivo 1ª a 4ª)", "Ensino fundamental eja - séries iniciais (supletivo 5ª a 8ª)", "Ensino médio, médio2º ciclo (científico,técnico e etc)", "Ensino médio especial", "Ensino médio eja(supletivo)", "Superior, aperfeiçoamento, especialização, mestrado, doutorado", "Alfabetização para adultos (mobral, etc)", "Nenhum"])
plt.figure(figsize=(20,10))
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right", fontsize=7)
plt.show()
# Out:
# /tmp/ipykernel_21747/2520530829.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right", fontsize=7)

# %%
plt.figure(figsize=(20,8))
sns.countplot(data, x="sexo")
# Out:
# <Axes: xlabel='sexo', ylabel='count'>

# %%
plt.figure(figsize=(20,8))
sns.countplot(data, x="ano")
# Out:
# <Axes: xlabel='ano', ylabel='count'>

# %%
sns.boxplot(data, y='idade', x='sexo')
# Out:
# <Axes: xlabel='sexo', ylabel='idade'>

# %%
sns.histplot(data, x='idade')
# Out:
# <Axes: xlabel='idade', ylabel='Count'>

# %%
df.max()
# Out:
# ano                                                          2023
# sigla_uf                                                       TO
# idade                                                         108
# fase_vida                                                   Idoso
# sexo                                                            M
# raca_cor                                                    Preta
# escolaridade    Superior, aperfeiçoamento, especialização, mes...
# peso                                                        183.0
# altura                                                      200.0
# imc                                                         74.38
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6719 entries, 0 to 318
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ano           6719 non-null   int64
#  1   sigla_uf      6719 non-null   object
#  2   idade         6719 non-null   int64
#  3   fase_vida     6719 non-null   object
#  4   sexo          6719 non-null   object
#  5   raca_cor      6719 non-null   object
#  6   escolaridade  6719 non-null   object
#  7   peso          6719 non-null   float64
#  8   altura        6719 non-null   float64
#  9   imc           6719 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 577.4+ KB

# %%
data.to_csv('bd_mqam1.csv')

# %%
dado = pd.read_csv("bd_mqam.csv")

# %%
dado
# Out:
#        Unnamed: 0   ano sigla_uf  idade               fase_vida sexo raca_cor  \
# 0               0  2008       BA      8  Entre 7 anos a 10 anos    M    Parda
# 1               1  2008       MG      4   Entre 2 anos a 5 anos    F    Parda
# 2               2  2008       PR      0  Entre 6 meses a 2 anos    F   Branca
# 3               3  2008       RS      4   Entre 2 anos a 5 anos    M   Branca
# 4               4  2008       PR      2   Entre 2 anos a 5 anos    M    Parda
# ...           ...   ...      ...    ...                     ...  ...      ...
# 15995         995  2023       RS     53                  Adulto    F   Branca
# 15996         996  2023       RS     14             Adolescente    M    Preta
# 15997         997  2023       MG     70                   Idoso    F    Parda
# 15998         998  2023       MG     49                  Adulto    M   Branca
# 15999         999  2023       RS     13             Adolescente    M   Branca
#
# ...
